# %% [markdown]
# # **<center> Análisis de Sentimientos de los candidatos presidenciales </br> Ecuador 2021, en la red social Twitter </center>**
# <h6>
#     <center> Miguel Angel Macias, Jonnathan Campoberde <br/>
#     <i>Universidad de Cuenca <br/>  <i>Facultad de Ingenieria - Escuela de Sistemas<br/> Cuenca, Ecuador</i>
#     <br/> { mangel.maciasn, jonnathan.campoberde }@ucuenca.edu.ec</center>
# <h6>

# %% [markdown]
# # **I.&emsp;Introducción**
# El presente trabajo tiene como objetivo emplear de manera práctica todos los conocimientos adquiridos en el transcurso de la asignatura “Text Mining”. Se trabajará con un dataset... . Se busca analizar el ..., detectando las ... por medio de ... . Todo esto con el propósito de ... .
#
# ## **1.1.&emsp;Objetivos del Proyecto**
# >El objetivo del proyecto es el Análisis de Sentimientos de los candidatos presidenciales de Ecuador 2021, para luego contrastar los resultados obtenidos con los resultados oficiales de las elecciones Posteriormente se desea responder a las preguntas definidas en 1.2.
#
# ## **1.2.&emsp;Preguntas de investigación**
# >- RQ1:     ¿Qué tan precisamente los datos de Twitter reflejan el sentimiento político en un proceso electoral?
# >- RQ1:     ¿En qué grado de aceptación se encuentran los candidatos dentro de la red Social Twitter?
# >- RQ3:     ¿Los resultadso oficiales son parecidos a los hallados en nuestro análisis?

# %% [markdown]
# # **IV.&emsp;SENTIMENT ANALYSIS**
#
# ## **4.1.&emsp; Reading dataset**
# >Para este paso...

# %%
import warnings

import pytz

import numpy as np              # Para operaciones matematicas
import pandas as pd             # Manejo de datos / dataframes
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
#%matplotlib inline

# %%
data_raw = '../data/raw'              # directorio que contiene toda la data sin manipular
data_processed = '../data/processed'  # directorio que contiene data procesada

# %%
df_arauz_tag = pd.read_csv(data_processed+"/arauz_tag.csv")
df_arauz_tag['created_at'] = pd.to_datetime(df_arauz_tag['created_at'], utc=pytz.UTC)
df_arauz_tag['user.created_at'] = pd.to_datetime(df_arauz_tag['user.created_at'], utc=pytz.UTC)
df_arauz_tag
# Out:
#                      created_at  favorite_count  \
# 0     2021-02-01 00:00:00+00:00               1
# 1     2021-01-31 23:59:54+00:00               0
# 2     2021-01-31 23:59:53+00:00               0
# 3     2021-01-31 23:59:30+00:00               0
# 4     2021-01-31 23:59:27+00:00               0
# ...                         ...             ...
# 12260 2021-02-01 00:09:31+00:00               0
# 12261 2021-02-01 00:07:41+00:00               3
# 12262 2021-02-01 00:04:17+00:00              19
# 12263 2021-02-01 00:01:11+00:00             321
# 12264 2021-02-01 00:00:06+00:00               6
#
#                                                full_text               id_str  \
# 0      elecciones2021ec las propuestas económicas de ...  1356029498307784705
# 1      el candidato andrés arauz no aceptó responder ...  1356029470554128384
# 2      candidato del correísmo andrés arauz aumentó s...  1356029467274194946
# 3      eln habría prestado $80.000 para la campaña de...  1356029369324593155
# 4      $1 000 a 1 millón de familias ayudará a dinami...  1356029360399151105
# ...                                                  ...                  ...
# 12260  ilustrame porque se vendían los cdrs al 40% y ...  1356031890243858433
# 12261  es imperativo que saquemos a estas ratas y más...  1356031431550631937
# 12262  según consejero esto es una infracción elector...  1356030576332066816
# 12263  14 años el correismo nos ha estado robando y t...  1356029796665470977
# 12264  lasso nebot y bucaram gobernaron con moreno ap...  1356029522987118592
#
#       metadata.iso_language_code     retweeted_status.created_at  \
# 0                             es                             NaN
# 1                             es  Sun Jan 31 15:51:12 +0000 2021
# 2                             es  Sun Jan 31 19:20:13 +0000 2021
# 3                             es  Sun Jan 31 16:18:52 +0000 2021
# 4                             es  Sun Jan 31 14:02:07 +0000 2021
# ...                          ...                             ...
# 12260                         es                             NaN
# 12261                         es                             NaN
# 12262                         es                             NaN
# 12263                         es                             NaN
# 12264                         es                             NaN
#
#                               retweeted_status.full_text  \
# 0                                                    NaN
# 1      El candidato Andrés Arauz @ecuarauz no aceptó ...
# 2      Candidato del Correísmo, Andrés Arauz aumentó ...
# 3      #ELN habría prestado $80.000 para la campaña d...
# 4      🇪🇨$1 000 A 1 MILLÓN DE FAMILIAS AYUDARÁ A DINA...
# ...                                                  ...
# 12260                                                NaN
# 12261                                                NaN
# 12262                                                NaN
# 12263                                                NaN
# 12264                                                NaN
#
#                 user.created_at  user.favourites_count  user.followers_count  \
# 0     2011-12-05 13:59:33+00:00                    269                 12756
# 1     2010-04-22 06:20:32+00:00                  15211                  1643
# 2     2020-11-24 03:29:03+00:00                  10157                   169
# 3     2010-08-20 20:40:04+00:00                   2653                   197
# 4     2011-12-07 02:30:28+00:00                  24781                   747
# ...                         ...                    ...                   ...
# 12260 2019-09-30 18:22:03+00:00                    802                    53
# 12261 2020-12-09 16:17:04+00:00                    217                    34
# 12262 2020-12-11 02:59:34+00:00                   2825                  2294
# 12263 2020-03-30 03:57:46+00:00                  22591                  4451
# 12264 2013-02-03 18:05:29+00:00                  98466                   621
#
#        user.friends_count          user.id_str      user.location  \
# 0                     288            429043466            Ecuador
# 1                    3233            135774682  Ombligo del mundo
# 2                     163  1331077287144517634                NaN
# 3                     226            180914917              Quito
# 4                    1006            430359745          Guayaquil
# ...                   ...                  ...                ...
# 12260                 552  1178736732826734599                NaN
# 12261                  55  1336706385728430081         Las Palmas
# 12262                1766  1337230403632050176                NaN
# 12263                1717  1244473781923516416                NaN
# 12264                1093           1145827459     Quito, Ecuador
#
#        user.verified  retweet_count  is_troll sentiment_tag  sentiment_sc
# 0              False              0     False      Negativo      0.303537
# 1              False            154     False      Negativo      0.012758
# 2              False            387      True      Negativo      0.011175
# 3              False             23     False      Negativo      0.404774
# 4              False             12     False      Negativo      0.046922
# ...              ...            ...       ...           ...           ...
# 12260          False              0     False      Negativo      0.001778
# 12261          False              0      True      Negativo      0.008126
# 12262          False             17     False      Negativo      0.034966
# 12263          False            114     False      Negativo      0.016784
# 12264          False              2     False      Negativo      0.035777
#
# [12265 rows x 18 columns]

# %% [markdown]
# ## **4.2.&emsp; Exploratory Data Analysis**
# >Para este paso...

# %%
#!pip install seaborn --upgrade

# %%
sns.set_style('darkgrid')
sns.set_context("paper", font_scale=1.3)

plt.figure(figsize=(12, 9))
g = sns.displot(df_arauz_tag, x="sentiment_sc", bins=10,
                hue="is_troll", stat="density", kde=True)
plt.title('Distribución de la polaridad de sentimiento para trolls y no trolls', fontsize=16)
plt.ylabel("Densidad", fontsize=13)
plt.xlabel("Puntaje de Sentimiento", fontsize=13)
plt.close(1)
plt.show()

# %% [markdown]
# #### _Null Data Analysis_
# > Los datos nulos que se muestran a continuacion se deben a que no fueron "retwiteados", es decir, `8367` son tweets originales a secas que no fueron respondidos por nadie

# %%
df_arauz_tag.isnull().sum().reset_index().rename(columns={'index':'columna', 0:'datos nulos'}).style
# Out:
# <style  type="text/css" >
# </style><table id="T_7a2cf230_701a_11eb_9798_2c600c1e4336" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >columna</th>        <th class="col_heading level0 col1" >datos nulos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row0_col0" class="data row0 col0" >created_at</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row0_col1" class="data row0 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row1_col0" class="data row1 col0" >favorite_count</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row1_col1" class="data row1 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row2_col0" class="data row2 col0" >full_text</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row2_col1" class="data row2 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row3_col0" class="data row3 col0" >id_str</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row3_col1" class="data row3 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row4_col0" class="data row4 col0" >metadata.iso_language_code</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row4_col1" class="data row4 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row5_col0" class="data row5 col0" >retweeted_status.created_at</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row5_col1" class="data row5 col1" >8367</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row6_col0" class="data row6 col0" >retweeted_status.full_text</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row6_col1" class="data row6 col1" >8367</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row7_col0" class="data row7 col0" >user.created_at</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row8_col0" class="data row8 col0" >user.favourites_count</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row8_col1" class="data row8 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row9_col0" class="data row9 col0" >user.followers_count</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row9_col1" class="data row9 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row10_col0" class="data row10 col0" >user.friends_count</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row10_col1" class="data row10 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row11_col0" class="data row11 col0" >user.id_str</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row11_col1" class="data row11 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row12_col0" class="data row12 col0" >user.location</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row12_col1" class="data row12 col1" >5185</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row13_col0" class="data row13 col0" >user.verified</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row13_col1" class="data row13 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row14_col0" class="data row14 col0" >retweet_count</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row14_col1" class="data row14 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row15_col0" class="data row15 col0" >is_troll</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row15_col1" class="data row15 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row16_col0" class="data row16 col0" >sentiment_tag</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row16_col1" class="data row16 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7a2cf230_701a_11eb_9798_2c600c1e4336level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row17_col0" class="data row17 col0" >sentiment_sc</td>
#                         <td id="T_7a2cf230_701a_11eb_9798_2c600c1e4336row17_col1" class="data row17 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
def larger_axlim( axlim ):
    """ argument axlim expects 2-tuple 
        returns slightly larger 2-tuple """
    axmin,axmax = axlim
    axrng = axmax - axmin
    new_min = axmin
    new_max = axmax + 0.05 * axrng
    return new_min,new_max

# %%
plt.figure(figsize=(8, 6))

ax = sns.countplot(x="is_troll", data=df_arauz_tag)
plt.title('Cantidad de cuentas trolls detectadas', fontsize=18)
plt.ylabel('Frecuencia', fontsize=13)
plt.xlabel('Es troll?', fontsize=13)

totalsize = df_arauz_tag['is_troll'].value_counts().sum()
ax.set_ylim(larger_axlim( ax.get_ylim()))

for p in ax.patches:
        ax.text(p.xy[0] + p.get_width()/3, p.xy[1] + p.get_height()+50, 
                str(round(p.get_height(), 3)) + " (" + 
                str(round(p.get_height()/totalsize*100,2)) + "%)", fontsize=13) 

plt.show();

# %% [markdown]
# #### _Ok_

# %% [markdown]
# ## **4.3.&emsp; Positive/Negative/Neutral Sentiment Analysis**
# >Para este paso...

# %%
plt.figure(figsize=(8, 6))

ax = sns.countplot(x="sentiment_tag", hue="is_troll", data=df_arauz_tag)

plt.title('Frecuencia de polaridad de sentimiento por trolls y no trolls', fontsize=18)
plt.ylabel('Frecuencia', fontsize=13)
plt.xlabel('Sentimiento', fontsize=13)

ax.set_ylim(larger_axlim( ax.get_ylim()))

for p in ax.patches:
        ax.text(p.xy[0] + p.get_width()/3, p.xy[1] + p.get_height()+50, 
                str(round(p.get_height(), 3)), fontsize=13) 

plt.show();

# %%
arauz = df_arauz_tag.resample('3H', on='created_at', offset='00Min00s').sentiment_sc.mean()
arauz_time_series = pd.DataFrame({'created_at':arauz.index, 'sentiment_sc':arauz.values})
mean_arauz = arauz_time_series['sentiment_sc'].mean()
# Out:
# 0.2054690978789197

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12, 9))
ax = sns.lineplot(x="created_at", y="sentiment_sc", estimator='mean', data=arauz_time_series)
plt.title('Evolucion de los sentimientos a traves del tiempo - Andres Arauz', fontsize=18)
plt.ylabel('Puntaje de Sentimiento', fontsize=13)
plt.xlabel('Linea de Tiempo', fontsize=13)
plt.xticks(rotation=45)
ax.axhline(mean_arauz,color='red',label='neutral')
ax.legend()
plt.show()
